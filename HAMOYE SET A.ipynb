# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
# %matplotlib inline
sns.set()
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
x = df.groupby("Area").sum(["Y2017"]).reset_index()

# %%
x.head()
# Out:
#            Area  Area Code  Item Code  Element Code      Y2014      Y2015  \
# 0       Algeria       5252    3532053       5017927  313375.33  324058.40
# 1        Angola       9968    3819908       5515088  208584.42  209565.67
# 2         Benin      68105    3453692       4852820  118050.79  108181.13
# 3      Botswana      27560    3704902       5259784   22339.92   23024.85
# 4  Burkina Faso     328297    3778795       5431243  105051.33  102701.22
#
#        Y2016      Y2017      Y2018
# 0  326007.41  325644.27  341729.98
# 1  214725.32  229159.57  235206.68
# 2  117963.59  124771.22  124960.70
# 3   22970.65   22101.30   23129.08
# 4  107702.27  101855.07  112970.72

# %%
max(x.Y2017)
# Out:
# 1483268.23

# %%
x[x.Y2017== 1483268.23]
# Out:
#        Area  Area Code  Item Code  Element Code       Y2014       Y2015  \
# 34  Nigeria     234366    3954357       5726937  1399542.19  1414362.83
#
#          Y2016       Y2017       Y2018
# 34  1482945.71  1483268.23  1499774.24

# %%
df[(df.Area=="Madagascar") & (df.Element== "Protein supply quantity (g/capita/day)")].Y2015.sum()
# Out:
# 173.04999999999998

# %%
x = x[["Area","Y2017"]]

# %%
x.Y2017.sort_values()
# Out:
# 42          0.00
# 16          0.00
# 9          59.84
# 38        442.34
# 36      12662.63
# 5       14650.74
# 21      19102.77
# 23      21267.96
# 3       22101.30
# 12      22729.91
# 18      23154.18
# 17      27979.64
# 24      29342.20
# 32      29874.89
# 7       29937.00
# 10      41181.68
# 43      49841.88
# 29      51114.83
# 14      54343.33
# 39      55311.33
# 8       71594.68
# 35      73663.69
# 48      75919.34
# 37      95681.15
# 20      98138.87
# 4      101855.07
# 47     103223.77
# 44     124167.20
# 2      124771.22
# 33     126707.58
# 25     131197.73
# 27     149928.33
# 28     156665.46
# 31     161407.98
# 26     181098.71
# 45     213950.38
# 11     224599.01
# 1      229159.57
# 6      232030.43
# 41     239931.92
# 22     264660.66
# 46     322616.85
# 0      325644.27
# 19     337599.06
# 30     388495.36
# 15     448683.76
# 40     517590.54
# 13     866379.92
# 34    1483268.23
# Name: Y2017, dtype: float64

# %%
x[x.Y2017==22729.91]
# Out:
#         Area     Y2017
# 12  Djibouti  22729.91

# %%
x[x.Y2017==23154.18]
# Out:
#       Area     Y2017
# 18  Gambia  23154.18

# %%
x[x.Y2017==21267.96]
# Out:
#        Area     Y2017
# 23  Lesotho  21267.96

# %%
x[x.Y2017==19102.77]
# Out:
#              Area     Y2017
# 21  Guinea-Bissau  19102.77

# %%
df.Area.nunique()
# Out:
# 49

# %%
df.isna().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
y = df.groupby("Element").sum().reset_index()

# %%
y
# Out:
#                                    Element  Area Code  Item Code  \
# 0                 Domestic supply quantity     708993   14197445
# 1                          Export Quantity     599910   11840553
# 2       Fat supply quantity (g/capita/day)     675050   13535000
# 3                                     Feed     176272    3538507
# 4                                     Food     663295   13285035
# 5            Food supply (kcal/capita/day)     674057   13511060
# 6      Food supply quantity (kg/capita/yr)     658446   13185401
# 7                          Import Quantity     688174   13795966
# 8                                   Losses     274353    5424803
# 9                    Other uses (non-food)     235554    4729749
# 10                              Processing     271940    5350416
# 11                              Production     526751   10450053
# 12  Protein supply quantity (g/capita/day)     675050   13535000
# ...

# %%
x = df.groupby("Item").sum(["Y2015","Y2018"]).reset_index()

# %%
x
# Out:
#                     Item  Area Code  Item Code  Element Code      Y2014  \
# 0      Alcohol, Non-Food      38447     752497       1515090    2403.00
# 1    Alcoholic Beverages      75016    1649136       2171381  102410.11
# 2        Animal Products      18060     397035         90990   11935.65
# 3            Animal fats      85279    1882494       2567303  209460.54
# 4    Apples and products      69280    1352989       1920418    9499.23
# ..                   ...        ...        ...           ...        ...
# 114    Vegetables, Other      77779    1518715       2275409  155038.96
# 115     Vegetal Products      18060     391905         90990  107145.19
# 116   Wheat and products      87073    1639683       2654934  232670.13
# 117                 Wine      66206    1319535       1818328    4497.36
# 118                 Yams      50798     970905       1525745  200396.96
#
#          Y2015      Y2016      Y2017      Y2018
# 0      2180.00    2223.00    2348.00    2293.00
# ...

# %%
x = df.groupby("Element").max(["Stock Variation"]).reset_index()

# %%
x
# Out:
#                                    Element  Area Code  Item Code  \
# 0                 Domestic supply quantity        276       2961
# 1                          Export Quantity        276       2961
# 2       Fat supply quantity (g/capita/day)        276       2961
# 3                                     Feed        276       2960
# 4                                     Food        276       2961
# 5            Food supply (kcal/capita/day)        276       2961
# 6      Food supply quantity (kg/capita/yr)        276       2961
# 7                          Import Quantity        276       2961
# 8                                   Losses        276       2949
# 9                    Other uses (non-food)        276       2961
# 10                              Processing        276       2948
# 11                              Production        276       2961
# 12  Protein supply quantity (g/capita/day)        276       2961
# ...
